# %%
import libpysal._kernels as _kernels

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = np.arange(101)
d = np.abs(x-50)

# %%
k50 = _kernels._kernel(d, 50)

# %%
k50
# Out:
# array([0.01315489, 0.01289699, 0.0126492 , 0.01241113, 0.01218242,
#        0.0119627 , 0.01175165, 0.01154894, 0.01135427, 0.01116734,
#        0.01098789, 0.01081565, 0.01065036, 0.0104918 , 0.01033973,
#        0.01019394, 0.01005423, 0.0099204 , 0.00979227, 0.00966967,
#        0.00955241, 0.00944036, 0.00933335, 0.00923124, 0.00913391,
#        0.00904122, 0.00895305, 0.00886928, 0.00878982, 0.00871455,
#        0.00864338, 0.00857622, 0.00851299, 0.00845361, 0.008398  ,
#        0.00834609, 0.00829783, 0.00825314, 0.00821198, 0.00817429,
#        0.00814003, 0.00810916, 0.00808163, 0.00805742, 0.0080365 ,
#        0.00801884, 0.00800442, 0.00799322, 0.00798523, 0.00798044,
#        0.00797885, 0.00798044, 0.00798523, 0.00799322, 0.00800442,
#        0.00801884, 0.0080365 , 0.00805742, 0.00808163, 0.00810916,
#        0.00814003, 0.00817429, 0.00821198, 0.00825314, 0.00829783,
#        0.00834609, 0.008398  , 0.00845361, 0.00851299, 0.00857622,
#        0.00864338, 0.00871455, 0.00878982, 0.00886928, 0.00895305,
#        0.00904122, 0.00913391, 0.00923124, 0.00933335, 0.00944036,
#        0.00955241, 0.00966967, 0.00979227, 0.0099204 , 0.01005423,
#        0.01019394, 0.01033973, 0.0104918 , 0.01065036, 0.01081565,
#        0.01098789, 0.01116734, 0.01135427, 0.01154894, 0.01175165,
#        0.0119627 , 0.01218242, 0.01241113, 0.0126492 , 0.01289699,
#        0.01315489])

# %%
df = pd.DataFrame(index=x)

# %%
for bw in [10, 20, 30, 40, 50]:
    df[f'g{bw}'] =  _kernels._kernel(d, bw)

# %%
df.head()
# Out:
#             g10       g20       g30       g40       g50
# 0  1.486720e-07  0.000876  0.003316  0.004566  0.004839
# 1  2.438961e-07  0.000992  0.003503  0.004710  0.004936
# 2  3.961299e-07  0.001120  0.003697  0.004855  0.005033
# 3  6.369825e-07  0.001261  0.003898  0.005001  0.005129
# 4  1.014085e-06  0.001416  0.004104  0.005148  0.005226

# %%
df.plot() # gaussian
# Out:
# <Axes: >

# %%
for bw in [10, 20, 30, 40, 50]:
    df[f't{bw}'] =  _kernels._kernel(d, bw, kernel='triangular')

# %%
df.plot() # gaussian
# Out:
# <Axes: >
